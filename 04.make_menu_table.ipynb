# %%
menu_dict = {
    "곰탕": ["나주곰탕"],
    "탕": ["대구탕", "장어탕", "황태국", "황태미역국", "술국"],
    "전골": ["추어전골", "해신탕", "해천탕"],
    "찌개": ["황태부대찌개"],
    "국수": ["어탕국수", "초계국수", "추어칼국수", "황태만두국", "황태콩나물해장국"],
    "기타": ["막회", "얼큰황태우거지탕"],
    "구이": ["가자미구이", "대하구이"],
    "조림": ["내장볶음", "대구뽈찜", "북어찜", "황태찜"],
    "회": ["광어회", "물회", "오징어회", "소라숙회", "산낙지회"],
    "밥": ["황태국밥", "황태떡국"],
    "반찬": ["낙지탕탕이", "낙지호롱", "알내장탕", "추어만두", "추어전", "아바이순대", "멍게(활)", "멍게비빔밥"],
    "파스타": ["까르보나라파스타", "날치알크림파스타", "까르보네피자", "봉골레파스타", "명란크림파스타", "바질크림파스타", "버섯리조또", "베이컨크림파스타", "새우오일파스타", "새우크림파스타", "새우토마토스파게티", "아라비아따파스타", "알리오올리오파스타", "푸팟퐁커리", "로제파스타", "빠네로제파스타", "풍기크림파스타", "시오라멘", "토마토리조또"],
    "덮밥": ["돈부리덮밥", "부타동", "차슈동", "카이센동", "훈제연어덮밥"],
    "피자": ["고르곤졸라피자", "까르보네피자", "돌체피자", "마르게리따피자", "비스마르크피자", "시카고피자", "어니언베이컨피자", "하와이안피자", "나폴리피자", "루꼴라피자", "풍기피자"],
    "튀김": ["가라아케", "깐쇼새우", "꽃빵", "튀김꽃빵"],
    "볶음": ["볶음쌀국수", "사천볶음쌀국수", "베트남식 볶음면", "중화볶음면"],
    "덮밥": ["나시고랭볶음밥"],
    "면": ["냉라멘", "닭고기쌀국수", "똠얌꿍쌀국수", "매운해물쌀국수", "소대창쌀국수", "소유라멘", "소힘줄(스지) 쌀국수", "양지쌀국수", "짬뽕 쌀국수", "짬뽕차돌쌀국수", "차돌양지쌀국수", "팟타이", "해물쌀국수", "해산물팟타이", "소곱창쌀국수"]
}

# %%
# 
reverse_menu_dict = {}
for dish, category_list in menu_dict.items():
    for category in category_list:
        if category not in reverse_menu_dict:
            reverse_menu_dict[category] = dish

# %%
import json
with open("menu.json", "w") as json_file:
    json.dump(reverse_menu_dict, json_file, indent=4)
